# %% [markdown]
# ## Figure_6_10Abs

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Neural Network performance on antibody-escape phenotype for 10 human monoclonal antibodies (Figure 6B; Table S3)

# %%
d_Abs = {'COV2-2050': [0.246994], 'COV2-2082': [0.09224], 'COV2-2094': [0.315764], 'COV2-2096': [0.19175], 'COV2-2165': [0.123021], 'COV2-2479': [0.130445], 'COV2-2499': [0.260286], 'COV2-2677': [0.29153], 'COV2-2832': [0.125652], 'rCR3022': [0.264203]}
df_perf = pd.DataFrame(data=d_Abs, index=["Performance"])

# %%
df_perf.iloc[0,]
# Out:
# COV2-2050    0.246994
# COV2-2082    0.092240
# COV2-2094    0.315764
# COV2-2096    0.191750
# COV2-2165    0.123021
# COV2-2479    0.130445
# COV2-2499    0.260286
# COV2-2677    0.291530
# COV2-2832    0.125652
# rCR3022      0.264203
# Name: Performance, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(df_perf.columns, df_perf.iloc[0,],hue=df_perf.columns,legend = False)
plt.ylim(0,0.4)
plt.xticks(rotation=45)
plt.title("Neural network model performance", fontsize=16)
plt.ylabel("Spearman correlation coefficient",fontsize=16)
plt.show()
# Out:
# C:\Users\wangb21\Anaconda3\envs\str_based_design\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Neural network derived antibody-escape phenotype for 10 human monoclonal antibodies (Figure 6A)

# %%
df_pred= pd.read_csv("../Results/NN_Derived_Phenotypic_Scores/10Abs_pred_score.csv")

# %%
pwd
# Out:
# 'C:\\Users\\wangb21\\Desktop\\Projects\\nn4dms-master\\pub\\Codes'

# %%
plt.figure(figsize=(20,5))
g=sns.scatterplot(x="site",y="pred_inv_boxcox",data=df_pred,hue="Ab type")
plt.xticks(np.arange(330, max(df_pred["site"])+1, 5))
plt.xlabel("Residue index",fontsize=16)
plt.ylabel("Antibody escape fraction",fontsize=16)
